# %%
import numpy as np
import pandas as pd
from scipy.stats import mannwhitneyu
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns

# Load your CSV data into a DataFrame
with open(r'/content/Accounts.csv', 'r', encoding='utf-8', errors='ignore') as data:
    data = pd.read_csv(data, engine='python', error_bad_lines=False)

# Split the data into two groups
human_data = data[data['Class'] == 1]
bot_data = data[data['Class'] == 0]

# Significance level
alpha = 0.05

# Store significant features and their effect sizes
significant_features = []
effect_sizes = []

for feature_name in data.columns[1:46]:
    feature_human = human_data[feature_name]
    feature_bot = bot_data[feature_name]

    # Perform Mann-Whitney U test
    _, p_value = stats.mannwhitneyu(feature_human, feature_bot)

    if p_value <= alpha:
        d = abs(np.mean(feature_human) - np.mean(feature_bot)) / np.sqrt((np.var(feature_human) + np.var(feature_bot)) / 2)

        if d < 0.33:
            effect_size_label = "Small"
        elif 0.33 <= d < 0.474:
            effect_size_label = "Medium"
        else:
            effect_size_label = "Large"

        significant_features.append((feature_name, p_value, d, effect_size_label))

# Print All Results
for feature_info in significant_features:
    feature_name, p_value, d, effect_size_label = feature_info
    print(f"Feature {feature_name}:")
    print(f"P-value: {p_value}")
    print(f"Cliff's d: {d} ({effect_size_label} effect)\n")

# significant features
significant_features.sort(key=lambda x: x[2], reverse=True)

# DataFrame from the sorted list
result_df = pd.DataFrame(significant_features, columns=['Feature', 'P-value', "Effect Size (Cliff's d)", 'Effect Size Label'])
result_df.to_csv('/content/Cliff Delta Test Results.csv', index=False)
# Out:
# <ipython-input-3-2bb28385f682>:10: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   data = pd.read_csv(data, engine='python', error_bad_lines=False)
# Feature Total Characters STD:
# P-value: 0.0
# Cliff's d: 1.4361625393325168 (Large effect)
#
# Feature Total Characters Mean:
# P-value: 0.0
# Cliff's d: 1.3251520890001496 (Large effect)
#
# Feature  Count Sentences STD:
# P-value: 0.0
# Cliff's d: 0.5047097518894644 (Large effect)
#
# Feature Count Sentences Mean:
# P-value: 2.6297706373104534e-88
# Cliff's d: 0.04939977336270182 (Small effect)
#
# Feature  Average Words Length STD:
# P-value: 0.0
# Cliff's d: 1.2458011862771388 (Large effect)
#
# Feature  Count Words STD:
# P-value: 0.0
# Cliff's d: 1.5733522520515162 (Large effect)
#
# Feature  Count Words Mean:
# P-value: 0.0
# Cliff's d: 1.233736855727159 (Large effect)
#
# Feature  Count Unique Words STD:
# P-value: 0.0
# Cliff's d: 1.7722851185884885 (Large effect)
#
# Feature  Count Unique Words Mean:
# P-value: 0.0
# Cliff's d: 1.321933318100912 (Large effect)
#
# Feature  Num Uppercase Chars STD:
# P-value: 0.0
# Cliff's d: 1.2868695556193872 (Large effect)
#
# Feature  Num Uppercase Chars Mean:
# P-value: 3.29234217904104e-55
# Cliff's d: 0.48682232854738955 (Large effect)
#
# Feature  Num Lowercase Chars STD:
# P-value: 0.0
# Cliff's d: 1.1478904720511445 (Large effect)
#
# Feature Num Lowercase Chars Mean:
# P-value: 0.0
# Cliff's d: 1.496046661878872 (Large effect)
#
# Feature  Num Uppercase Words STD:
# P-value: 0.0
# Cliff's d: 1.1440269606574955 (Large effect)
#
# Feature  Num Uppercase Words Mean:
# P-value: 0.0
# Cliff's d: 1.1026121532599513 (Large effect)
#
# Feature  Num lowercase Words STD:
# P-value: 0.0
# Cliff's d: 1.3694747319992508 (Large effect)
#
# Feature  Num lowercase Words Mean:
# P-value: 0.0
# Cliff's d: 1.2244743751845961 (Large effect)
#
# Feature  Count Punctuations STD:
# P-value: 0.0
# Cliff's d: 0.8160485016955705 (Large effect)
#
# Feature Count Punctuations Mean:
# P-value: 3.5600883738584803e-06
# Cliff's d: 0.09204335253211036 (Small effect)
#
# Feature Count Urls STD:
# P-value: 0.0
# Cliff's d: 2.1296297801474933 (Large effect)
#
# Feature  Count Urls Mean:
# P-value: 0.0
# Cliff's d: 1.4411928499101794 (Large effect)
#
# Feature  Count Blanks STD:
# P-value: 0.0
# Cliff's d: 1.5235376561446377 (Large effect)
#
# Feature Count Blanks Mean:
# P-value: 0.0
# Cliff's d: 1.2241534512558416 (Large effect)
#
# Feature Count Numbers STD:
# P-value: 0.0
# Cliff's d: 1.2464401030177015 (Large effect)
#
# Feature Count Numbers Mean:
# P-value: 1.734212323930302e-232
# Cliff's d: 0.5036760343950687 (Large effect)
#
# Feature Count Special Characters STD:
# P-value: 0.0
# Cliff's d: 0.8160485016955705 (Large effect)
#
# Feature Count Special Characters Mean:
# P-value: 3.5600883738584803e-06
# Cliff's d: 0.09204335253211036 (Small effect)
#
# Feature Coleman Liau Index STD:
# P-value: 0.0
# Cliff's d: 0.586107555701263 (Large effect)
#
# Feature Coleman Liau Index Mean:
# P-value: 3.6609190508170024e-32
# Cliff's d: 0.23604793711615885 (Small effect)
#
# Feature  Automated Readability Index STD:
# P-value: 0.0
# Cliff's d: 0.9375159245245911 (Large effect)
#
# Feature Automated Readability Index Mean:
# P-value: 4.236517397062096e-82
# Cliff's d: 0.3536693637627244 (Medium effect)
#
# Feature  Dale Chall Readability STD:
# P-value: 0.0
# Cliff's d: 1.5733539797067202 (Large effect)
#
# Feature Dale Chall Readability Mean:
# P-value: 0.0
# Cliff's d: 1.2337294387549458 (Large effect)
#
# Feature Smog Index STD:
# P-value: 1.710874030867137e-244
# Cliff's d: 0.9549649832218614 (Large effect)
#
# Feature Smog Index Mean:
# P-value: 0.0
# Cliff's d: 1.7603300661827768 (Large effect)
#
# Feature Linsear Write STD:
# P-value: 0.0
# Cliff's d: 1.2814476053505985 (Large effect)
#
# Feature Linsear Write Mean:
# P-value: 0.0
# Cliff's d: 1.631703884915925 (Large effect)
#
# Feature  Flesch Kincaid Grade Level STD:
# P-value: 3.2884765519596046e-136
# Cliff's d: 0.7321280160243172 (Large effect)
#
# Feature Flesch Kincaid Grade Level Mean:
# P-value: 0.0
# Cliff's d: 1.6103604985909612 (Large effect)
#
# Feature  Flesch Reading Ease STD:
# P-value: 0.0
# Cliff's d: 1.7481644611760407 (Large effect)

# %%
# Melt the data to a long format for seaborn violin plot
melted_data = pd.melt(data, id_vars=['Class'], value_vars=result_df['Feature'])

# Violin plots
plt.figure(figsize=(15, 8))
sns.set(style="whitegrid")

for feature_info in significant_features:
    feature_name, _, d, _ = feature_info

    # Filter data
    melted_data_feature = melted_data[melted_data['variable'] == feature_name]

    # Create violin plot
    plt.figure(figsize=(10, 6))
    sns.violinplot(x='variable', y='value', hue='Class', data=melted_data_feature)

    # Annotate with effect size (Cliff's d) and class distribution values
    plt.text(0.5, 0.9, f"Cliff's d: {d:.4f}", horizontalalignment='center', verticalalignment='center', transform=plt.gca().transAxes)
    class_counts = melted_data_feature.groupby(['Class']).size().reset_index(name='Count')
    plt.xticks(rotation=0)
    plt.savefig(f'/content/Violin_Plot_{feature_name}.png')
    plt.show()
