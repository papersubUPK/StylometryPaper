# %%
# Account Features
import matplotlib.pyplot as plt
from collections import Counter

features = [
    "Count of Numbers STD",
    "Average Words Length Mean",
    "Coleman Liau Index Mean",
    "Automated Readability Index STD",
    "Number of Uppercase Words Mean",
    "Total Characters Mean",
    "Number of Uppercase Words STD",
    "Dale Chall Readability STD",
    "Smog Index Mean",
    "Average Words Length STD",
    "Number of Uppercase Words STD",
    "Linsear Write Mean",
    "Number of Uppercase Characters STD",
    "Count of Unique Words Mean",
    "Gunning Fog Mean",
    "Count of Unique Words STD",
    "Coleman Liau Index STD",
    "Flesch Kincaid Grade Level Mean",
    "Dale Chall Readability STD",
    "Automated Readability Index Mean",
    "Linsear Write Mean",
    "Average Words Length STD",
    "Number of Uppercase Characters STD",
    "Count of Unique Words STD",
    "Flesch Reading Ease STD",
    "Number of Uppercase Words Mean",
    "Count of Numbers Mean",
    "Number of Uppercase Words STD",
    "Number of Lowercase Characters Mean",
    "Number of Lowercase Characters STD",
    "Flesch Kincaid Grade Level Mean",
    "Flesch Reading Ease STD",
    "Total Characters STD",
    "Smog Index STD",
    "Gunning Fog STD",
    "Total Characters Mean",
    "Number of Lowercase Characters STD",
    "Coleman Liau Index Mean",
    "Count of Special Characters Mean",
    "Flesch Kincaid Grade Level STD",
    "Total Characters Mean",
    "Flesch Reading Ease STD",
    "Number of Lowercase Characters Mean",
    "Coleman Liau Index Mean",
    "Number of Uppercase Characters Mean",
    "Gunning Fog Mean",
    "Number of Uppercase Words Mean",
    "Count of Punctuations Mean",
    "Count of Punctuations STD",
    "Number of lowercase Words Mean",
]
# Count  each feature
feature_counts = Counter(features)

# Get top 10 features
top_features = dict(feature_counts.most_common(10))

# Plotting with pie chart
plt.figure(figsize=(5, 5))
text_properties = {'fontsize': 8, 'multialignment': 'center'}
labels_with_linebreaks = [
    f"{key[:key.find(' ')+1]}\n{key[key.find(' ')+1:key.rfind(' ')+1]}\n{key[key.rfind(' ')+1:]}"
    if ' ' in key
    else key
    for key in top_features.keys()
]
plt.pie(top_features.values(), labels=labels_with_linebreaks, autopct='%1.1f%%', startangle=190, textprops=text_properties)
plt.title('', fontsize=10)
plt.savefig('Account.png', dpi=600, bbox_inches='tight')
plt.show()

# %%
# Tweets Features
import matplotlib.pyplot as plt
from collections import Counter

# Assuming features is a list of features
TFeatures = [
    "Count of Unique Words",
    "Gunning Fog",
    "Count of Blanks",
    "Count of Special Characters",
    "Dale Chall Readability",
    "Count of Punctuations",
    "Flesch Reading Ease",
    "Linsear Write",
    "Number of Uppercase Characters",
    "Average Words Length",
    "Flesch Reading Ease",
    "Count of Unique Words",
    "Number of Lowercase Words",
    "Count of Words",
    "Automated Readability Index",
    "Total Characters",
    "Smog Index",
    "Count of Numbers",
    "Gunning Fog",
    "Coleman Liau Index",
    "Number of Lowercase Characters",
    "Flesch Reading Ease",
    "Count of Numbers",
    "Count of Words",
    "Count of Unique Words",
    "Number of Lowercase Words",
    "Count of Punctuations",
    "Flesch Kincaid Grade Level",
    "Count of Blanks",
    "Count of Special Characters",
    "Flesch Reading Ease",
    "Number of Uppercase Characters",
    "Count of Unique Words",
    "Dale Chall Readability",
    "Count of Numbers",
    "Count of Special Characters",
    "Linsear Write",
    "Count of Punctuations",
    "Count of Blanks",
    "Gunning Fog",
    "Total Characters",
    "Coleman Liau Index",
    "Smog Index",
    "Number of Lowercase Words",
    "Count of Words",
    "Count of Unique Words",
    "Count of Blanks",
    "Gunning Fog",
    "Count of Numbers",
    "Flesch Kincaid Grade Level",
]
# Count
feature_counts = Counter(TFeatures)

# Get top 10 features
top_features = dict(feature_counts.most_common(10))
plt.figure(figsize=(5, 5))
text_properties = {'fontsize': 8, 'multialignment': 'center'}
labels_with_linebreaks = [f"{key[:key.find(' ')+1]}\n{key[key.find(' ')+1:]}" if ' ' in key else key for key in top_features.keys()]

plt.pie(top_features.values(), labels=labels_with_linebreaks, autopct='%1.1f%%', startangle=140, textprops=text_properties)
plt.title('', fontsize=10)
plt.savefig('Account.png', dpi=600, bbox_inches='tight')
plt.show()
